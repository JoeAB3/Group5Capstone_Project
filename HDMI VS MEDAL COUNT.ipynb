# %%
#Initial Imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from numpy import asarray

# %%
#Load the datasets
hdmi_df = pd.read_csv("Human Development Index (HDI).csv", encoding='latin-1')
medal_df = pd.read_csv("Rio 2016 - Olympic Medal Count.csv",index_col=[0], encoding='latin-1')
#Source for Data: https://app.box.com/s/kjr3r48avq44swk74lvdi54xc5rxf139

# %%
hdmi_df.head(10)
# Out:
#   HDI Rank               Country   1990  Unnamed: 3   1991  Unnamed: 5   1992  \
# 0      169           Afghanistan  0.302         NaN  0.307         NaN  0.316
# 1       69               Albania   0.65         NaN  0.631         NaN  0.615
# 2       91               Algeria  0.572         NaN  0.576         NaN  0.582
# 3       36               Andorra     ..         NaN     ..         NaN     ..
# 4      148                Angola     ..         NaN     ..         NaN     ..
# 5       78   Antigua and Barbuda     ..         NaN     ..         NaN     ..
# 6       46             Argentina  0.718         NaN  0.725         NaN   0.73
# 7       81               Armenia  0.654         NaN  0.648         NaN  0.618
# 8        8             Australia  0.871         NaN  0.871         NaN  0.873
# 9       18               Austria  0.803         NaN  0.808         NaN  0.813
#
#    Unnamed: 7   1993  Unnamed: 9  ... Unnamed: 51   2015 Unnamed: 53   2016  \
# ...

# %%
medal_df = medal_df.astype(str)

# %%
#Create a new DataFrame that holds only the 2016 Human Development Index and Rank
hdmi_2016_df = hdmi_df[["Country", "HDI Rank", "2016"]].copy()
hdmi_2016_df = hdmi_2016_df.set_index("Country")
hdmi_2016_df = hdmi_2016_df.dropna()

hdmi_2016_df.head(20)
# Out:
#                      HDI Rank   2016
# Country
#  Afghanistan              169  0.502
#  Albania                   69  0.788
#  Algeria                   91  0.743
#  Andorra                   36  0.866
#  Angola                   148  0.578
#  Antigua and Barbuda       78  0.765
#  Argentina                 46  0.839
#  Armenia                   81  0.766
#  Australia                  8  0.939
#  Austria                   18  0.917
#  Azerbaijan                88  0.751
#  Bahamas                   58   0.81
#  Bahrain                   42  0.853
#  Bangladesh               133  0.606
#  Barbados                  58  0.811
#  Belarus                   53  0.815
#  Belgium                   14  0.924
#  Belize                   110  0.717
#  Benin                    158  0.533
#  Bhutan                   129  0.637

# %%
# Merge the two dataframes
#medal_hdi_df = pd.merge(left=hdmi_2016_df, right=medal_df, how='left', left_on='Country', right_on='Country')
#medal_hdi_df.head(15)
#medal_hdi_df = pd.concat([medal_df, hdmi_2016_df], axis = 1)
